# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarath-Mohan9469545/computing_lab_exp/blob/main/make_blob.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_blobs

# %%
x, y = make_blobs(n_samples=2000, centers=2, n_features=2)

# %%
x
# Out:
# array([[1.45127863, 7.58526888],
#        [3.27016732, 9.72343557],
#        [2.81042711, 5.48247089],
#        ...,
#        [4.42774388, 8.22179902],
#        [3.35638526, 9.22987788],
#        [2.83608694, 6.72211962]])

# %%
y
# Out:
# array([1, 1, 0, ..., 1, 1, 1])

# %%
import pandas as pd
new_df=pd.DataFrame(x,columns=["X_axis","Y_axis"])

# %%
new_df
# Out:
#         X_axis    Y_axis
# 0     1.451279  7.585269
# 1     3.270167  9.723436
# 2     2.810427  5.482471
# 3     2.814463  7.837816
# 4     5.721860  6.104579
# ...        ...       ...
# 1995  6.527108  4.193823
# 1996  4.590705  4.788760
# 1997  4.427744  8.221799
# 1998  3.356385  9.229878
# 1999  2.836087  6.722120
#
# [2000 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.33)

# %%
X_train
# Out:
# array([[5.42815108, 4.14442038],
#        [4.46652563, 6.95517264],
#        [5.98073604, 4.92360491],
#        ...,
#        [3.29512304, 7.5815264 ],
#        [5.22563648, 7.7315134 ],
#        [4.2974119 , 7.87836778]])

# %%
X_train=pd.DataFrame(X_train,columns=["X_axis","Y_axis"])

# %%
X_train
# Out:
#         X_axis    Y_axis
# 0     5.428151  4.144420
# 1     4.466526  6.955173
# 2     5.980736  4.923605
# 3     5.198082  5.494768
# 4     3.625589  7.955208
# ...        ...       ...
# 1335  5.607458  6.741480
# 1336  5.641277  6.112925
# 1337  3.295123  7.581526
# 1338  5.225636  7.731513
# 1339  4.297412  7.878368
#
# [1340 rows x 2 columns]

# %%
import matplotlib.pyplot as plt
x_axis=X_train["X_axis"]
y_axis=X_train["Y_axis"]
plt.scatter(x_axis,y_axis,s=10, cmap="y")
plt.xlabel("X")
plt.ylabel("Y")
plt.rcParams["figure.figsize"]=(10,8)
plt.show()

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=2, random_state=0).fit(X_train)

# %%
c=kmeans.cluster_centers_
c
# Out:
# array([[5.25049366, 5.43438269],
#        [3.36867936, 7.77587551]])

# %%
import matplotlib.pyplot as plt
x_axis=X_train["X_axis"]
y_axis=X_train["Y_axis"]
labels=kmeans.labels_
plt.scatter(x_axis,y_axis, s=20,c=labels,cmap="rainbow")
plt.scatter(c[0][0],c[0][1],s=100,color="orange")
plt.scatter(c[1][0],c[1][1],s=100,color="green")

plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
X_test=pd.DataFrame(X_test,columns=["X_axis","Y_axis"])

# %%
res1=kmeans.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(res1, y_test)
# Out:
# 0.9227272727272727
