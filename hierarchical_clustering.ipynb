# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarath-Mohan9469545/computing_lab_exp/blob/main/hierarchical_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from scipy.cluster import hierarchy
import pandas as pd
data=pd.read_csv("/content/Iris (1).csv",index_col=0)

# %%
data
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# Id
# 1              5.1           3.5            1.4           0.2     Iris-setosa
# 2              4.9           3.0            1.4           0.2     Iris-setosa
# 3              4.7           3.2            1.3           0.2     Iris-setosa
# 4              4.6           3.1            1.5           0.2     Iris-setosa
# 5              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 146            6.7           3.0            5.2           2.3  Iris-virginica
# 147            6.3           2.5            5.0           1.9  Iris-virginica
# 148            6.5           3.0            5.2           2.0  Iris-virginica
# 149            6.2           3.4            5.4           2.3  Iris-virginica
# 150            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)

# %%
x=data[["SepalLengthCm",	"SepalWidthCm",	"PetalLengthCm",	"PetalWidthCm"]]

# %%
pca=pca.fit_transform(x)

# %%
df=pd.DataFrame(pca,columns=["PC1","PC2"])

# %%
df
# Out:
#           PC1       PC2
# 0   -2.684207  0.326607
# 1   -2.715391 -0.169557
# 2   -2.889820 -0.137346
# 3   -2.746437 -0.311124
# 4   -2.728593  0.333925
# ..        ...       ...
# 145  1.944017  0.187415
# 146  1.525664 -0.375021
# 147  1.764046  0.078519
# 148  1.901629  0.115877
# 149  1.389666 -0.282887
#
# [150 rows x 2 columns]

# %%
y=hierarchy.linkage(df,"single")
z=hierarchy.dendrogram(y)

# %%
y=hierarchy.linkage(df,"complete")
z=hierarchy.dendrogram(y)

# %%
y=hierarchy.linkage(df,"average")
z=hierarchy.dendrogram(y)

# %%
import random
data=pd.read_csv("/content/Iris (1).csv",index_col=0,)
data=data[:50]
data
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# Id
# 1             5.1           3.5            1.4           0.2  Iris-setosa
# 2             4.9           3.0            1.4           0.2  Iris-setosa
# 3             4.7           3.2            1.3           0.2  Iris-setosa
# 4             4.6           3.1            1.5           0.2  Iris-setosa
# 5             5.0           3.6            1.4           0.2  Iris-setosa
# 6             5.4           3.9            1.7           0.4  Iris-setosa
# 7             4.6           3.4            1.4           0.3  Iris-setosa
# 8             5.0           3.4            1.5           0.2  Iris-setosa
# 9             4.4           2.9            1.4           0.2  Iris-setosa
# 10            4.9           3.1            1.5           0.1  Iris-setosa
# 11            5.4           3.7            1.5           0.2  Iris-setosa
# 12            4.8           3.4            1.6           0.2  Iris-setosa
# ...

# %%
x=data[["SepalLengthCm",	"SepalWidthCm",	"PetalLengthCm",	"PetalWidthCm"]]

# %%
x
# Out:
#     SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Id
# 1             5.1           3.5            1.4           0.2
# 2             4.9           3.0            1.4           0.2
# 3             4.7           3.2            1.3           0.2
# 4             4.6           3.1            1.5           0.2
# 5             5.0           3.6            1.4           0.2
# 6             5.4           3.9            1.7           0.4
# 7             4.6           3.4            1.4           0.3
# 8             5.0           3.4            1.5           0.2
# 9             4.4           2.9            1.4           0.2
# 10            4.9           3.1            1.5           0.1
# 11            5.4           3.7            1.5           0.2
# 12            4.8           3.4            1.6           0.2
# 13            4.8           3.0            1.4           0.1
# 14            4.3           3.0            1.1           0.1
# ...

# %%
pca=PCA(n_components=2)
pca=pca.fit_transform(x)
df=pd.DataFrame(pca,columns=["PC1","PC2"])

# %%
df=pd.DataFrame(pca,columns=["PC1","PC2"])

# %%
df
# Out:
#          PC1       PC2
# 0   0.113840  0.029057
# 1  -0.387581 -0.159565
# 2  -0.383029  0.134706
# 3  -0.504328  0.035010
# 4   0.120855  0.151611
# 5   0.650766 -0.069369
# 6  -0.285857  0.261556
# 7  -0.016938 -0.021475
# 8  -0.794320  0.081436
# 9  -0.311509 -0.138265
# 10  0.470452 -0.077961
# 11 -0.140701  0.050546
# 12 -0.461244 -0.090471
# 13 -0.822783  0.359982
# 14  0.929406  0.013044
# 15  1.199850  0.156988
# 16  0.612852  0.127285
# 17  0.120882  0.020555
# 18  0.769950 -0.304606
# 19  0.351269  0.157276
# 20  0.268502 -0.362172
# 21  0.284675  0.086812
# 22 -0.183542  0.590635
# 23  0.016131 -0.267862
# 24 -0.112264 -0.096944
# 25 -0.302003 -0.318485
# 26  0.006625 -0.087643
# 27  0.189939 -0.080699
# 28  0.106825 -0.093497
# 29 -0.354593 -0.012784
# 30 -0.361608 -0.135338
# 31  0.263629 -0.280850
# 32  0.624712  0.299572
# 33  0.895774  0.220417
# 34 -0.311509 -0.138265
# 35 -0.192646  0.002092
# 36  0.370844 -0.164150
# 37 -0.311509 -0.138265
# 38 -0.730163  0.192560
# ...

# %%
y=hierarchy.linkage(df,"single")
z=hierarchy.dendrogram(y)

# %%
y=hierarchy.linkage(df,"complete")
z=hierarchy.dendrogram(y)

# %%
y=hierarchy.linkage(df,"average")
z=hierarchy.dendrogram(y)

# %%
data1=pd.read_csv("/content/chrome.csv")
data1
# Out:
#                 x           y  color
# 0      317.614913  197.197881      2
# 1      187.085153  164.653509      0
# 2      245.989615  233.783184      2
# 3      356.170303  206.712568      2
# 4      424.640194  141.090956      1
# ...           ...         ...    ...
# 11088  371.716860  129.744133      1
# 11089  405.444240  130.461651      1
# 11090  261.669626  268.523020      2
# 11091  286.263353  170.122494      2
# 11092  255.261636  232.507967      2
#
# [11093 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
x=data1[["x",	"y"]]

# %%
y=hierarchy.linkage(x,"average")
plt.figure(figsize=(15,10))
z=hierarchy.dendrogram(y)
plt.show()
